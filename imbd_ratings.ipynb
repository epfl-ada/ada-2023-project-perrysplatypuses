# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from utils.imdb_ratings import get_imdb_ratings

# %%
movies = pd.read_csv(
    'data/MovieSummaries/movie.metadata.tsv', 
    sep='\t', 
    names=['wiki_id', 'freebase_id', 'title', 'release_date', 'revenue', 'runtime', 'languages', 'countries', 'genres']
)

# %%
title_and_rating = get_imdb_ratings(5000000)

# %%
title_and_rating.merge(movies, left_on='primaryTitle', right_on='title')
# Out:
#                  primaryTitle  averageRating   wiki_id freebase_id  \
# 0       !Women Art Revolution       6.800000  29988427  /m/0cryrj0
# 1                           $       6.300000   4213160   /m/0bq8q8
# 2                       $9.99       6.700000  20624798  /m/05222ld
# 3                         '68       5.900000   2250713   /m/06z7m4
# 4                 'Gator Bait       5.400000  10331139  /m/02q8q5n
# ...                       ...            ...       ...         ...
# 48540  È l'amor che mi rovina       5.000000  23687589  /m/06zm7fp
# 48541             Échangistes       4.000000  27932113  /m/0ch3s8r
# 48542               Édes Anna       7.400000  21534981  /m/05h1xdc
# 48543                   Élisa       6.594931   1719500   /m/05qyl8
# 48544                Ödipussi       7.400000  13983035  /m/03cq2ws
#
#                         title release_date  revenue  runtime  \
# 0       !Women Art Revolution      2010-09      NaN     83.0
# ...
