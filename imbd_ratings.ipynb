# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from utils.imdb_ratings import get_imdb_ratings, movies_with_imdb_rating

# %% [markdown]
# For this code to work, in the data folder there should be folder `IMDB` and in that folder should be files `ratinds.tsv` (title.ratings.tsv.gz) and `titles.tsv` (title.basics.tsv.gz)

# %%
movies = pd.read_csv(
    'data/MovieSummaries/movie.metadata.tsv', 
    sep='\t', 
    names=['wiki_id', 'freebase_id', 'title', 'release_date', 'revenue', 'runtime', 'languages', 'countries', 'genres']
)

# %%
title_and_rating = movies_with_imdb_rating(movies)
title_and_rating
# Out:
#                      primaryTitle startYear  averageRating  numVotes  \
# 0                      Miss Jerry      1894            5.3       208
# 1   The Corbett-Fitzsimmons Fight      1897            5.3       485
# 2     The Story of the Kelly Gang      1906            6.0       855
# 3              Robbery Under Arms      1907            4.3        25
# 4                          Hamlet      1908            2.9        27
# ..                            ...       ...            ...       ...
# 6        The Mistress of Atlantis      1932            5.3        67
# 7     The Hunchback of Notre Dame      1996            1.9        71
# 8              Pontianak Menjerit      2005            6.0         8
# 9                           Kisan      2006            5.1         9
# 10                           Gaja      2008            6.8       112
#
#      wiki_id freebase_id                          title release_date  \
# ...
