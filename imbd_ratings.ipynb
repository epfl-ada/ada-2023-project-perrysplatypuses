# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from utils.imdb_ratings import get_imdb_ratings

# %%
movies = pd.read_csv(
    'data/MovieSummaries/movie.metadata.tsv', 
    sep='\t', 
    names=['wiki_id', 'freebase_id', 'title', 'release_date', 'revenue', 'runtime', 'languages', 'countries', 'genres']
)

# %%
title_and_rating = get_imdb_ratings(500000)

# %%
title_and_rating.merge(movies, left_on='primaryTitle', right_on='title')
# Out:
#                    primaryTitle  averageRating   wiki_id freebase_id  \
# 0                             $       6.300000   4213160   /m/0bq8q8
# 1                           '68       5.900000   2250713   /m/06z7m4
# 2                   'Gator Bait       5.400000  10331139  /m/02q8q5n
# 3                 'If Only' Jim       2.900000  13504095  /m/03c7j17
# 4      'Neath the Arizona Skies       5.100000   3610422   /m/09pt2f
# ...                         ...            ...       ...         ...
# 42007        È caduta una donna       5.200000  23688125  /m/06zqdxq
# 42008    È l'amor che mi rovina       5.000000  23687589  /m/06zm7fp
# 42009                 Édes Anna       7.400000  21534981  /m/05h1xdc
# 42010                     Élisa       6.594931   1719500   /m/05qyl8
# 42011                  Ödipussi       7.400000  13983035  /m/03cq2ws
#
#                           title release_date  revenue  runtime  \
# 0                             $   1971-12-17      NaN    119.0
# 1                           '68         1988      NaN     98.0
# 2                   'Gator Bait         1974      NaN     91.0
# 3                 'If Only' Jim         1920      NaN      NaN
# 4      'Neath the Arizona Skies         1934      NaN     52.0
# ...                         ...          ...      ...      ...
# 42007        È caduta una donna   1941-12-17      NaN     72.0
# 42008    È l'amor che mi rovina         1951      NaN      NaN
# 42009                 Édes Anna   1958-11-06      NaN     84.0
# 42010                     Élisa         1995      NaN    115.0
# 42011                  Ödipussi   1988-03-10      NaN     88.0
#
#                                                languages  \
# 0                     {"/m/02h40lc": "English Language"}
# 1                     {"/m/02h40lc": "English Language"}
# 2                     {"/m/02h40lc": "English Language"}
# 3      {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 4                     {"/m/02h40lc": "English Language"}
# ...                                                  ...
# 42007                 {"/m/02bjrlw": "Italian Language"}
# 42008                 {"/m/02bjrlw": "Italian Language"}
# 42009               {"/m/02ztjwg": "Hungarian language"}
# 42010                  {"/m/064_8sq": "French Language"}
# 42011                  {"/m/04306rv": "German Language"}
#
#                                                countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1      {"/m/09c7w0": "United States of America", "/m/...
# 2              {"/m/09c7w0": "United States of America"}
# 3              {"/m/09c7w0": "United States of America"}
# 4              {"/m/09c7w0": "United States of America"}
# ...                                                  ...
# 42007                              {"/m/03rjj": "Italy"}
# 42008                              {"/m/03rjj": "Italy"}
# 42009                            {"/m/03gj2": "Hungary"}
# 42010                            {"/m/0f8l9c": "France"}
# 42011                            {"/m/0345h": "Germany"}
#
#                                                   genres
# 0      {"/m/0lsxr": "Crime Fiction", "/m/04btyz": "He...
# 1      {"/m/07s9rl0": "Drama", "/m/04xvlr": "Period p...
# 2      {"/m/01jfsb": "Thriller", "/m/02kdv5l": "Actio...
# 3      {"/m/06ppq": "Silent film", "/m/0hfjk": "Weste...
# 4      {"/m/03btsm8": "Action/Adventure", "/m/0hfjk":...
# ...                                                  ...
# 42007  {"/m/07s9rl0": "Drama", "/m/01g6gs": "Black-an...
# 42008                             {"/m/01z4y": "Comedy"}
# 42009  {"/m/07s9rl0": "Drama", "/m/01g6gs": "Black-an...
# 42010  {"/m/04228s": "Road movie", "/m/07s9rl0": "Dra...
# 42011                             {"/m/01z4y": "Comedy"}
#
# [42012 rows x 11 columns]
